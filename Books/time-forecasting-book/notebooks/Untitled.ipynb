# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('../test-data/jj.csv')

# %%
df
# Out:
#           date   data
# 0   1960-01-01   0.71
# 1   1960-04-01   0.63
# 2   1960-07-02   0.85
# 3   1960-10-01   0.44
# 4   1961-01-01   0.61
# ..         ...    ...
# 79  1979-10-01   9.99
# 80  1980-01-01  16.20
# 81  1980-04-01  14.67
# 82  1980-07-02  16.02
# 83  1980-10-01  11.61
#
# [84 rows x 2 columns]

# %%
df.head()
# Out:
#          date  data
# 0  1960-01-01  0.71
# 1  1960-04-01  0.63
# 2  1960-07-02  0.85
# 3  1960-10-01  0.44
# 4  1961-01-01  0.61

# %%
df.tail()
# Out:
#           date   data
# 79  1979-10-01   9.99
# 80  1980-01-01  16.20
# 81  1980-04-01  14.67
# 82  1980-07-02  16.02
# 83  1980-10-01  11.61

# %%
train = df[:-4]
test = df[-4:]

# %%
import numpy as np

# %%
# 訓練データせっとのdata列の算術平均を計算

# %%
historical_mean = np.mean(train['data'])
print(historical_mean)
# Out:
# 4.3084999875

# %%
test.loc[:, 'pred_mean'] = historical_mean

# %%
eeew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-698255c92708> in <module>
# ----> 1 pred_mean
#
# NameError: name 'pred_mean' is not defined
