# %%
import pandas as pd

# %%
pd.options.mode.chained_assisgnment = None
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-3-694f0ba07dd2> in <module>
# ----> 1 pd.options.mode.chained_assisgnment = None
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_config/config.py in __setattr__(self, key, val)
#     194             _set_option(prefix, val)
#     195         else:
# --> 196             raise OptionError("You can only set the value of existing options")
#     197
#     198     def __getattr__(self, key: str):
#
# OptionError: 'You can only set the value of existing options'
